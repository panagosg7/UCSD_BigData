# %% [markdown]
# # Station partitioning

# %%
import pandas as pd
import numpy as np
import sklearn as sk
print 'pandas version: ',pd.__version__
print 'numpy version:',np.__version__
print 'sklearn version:',sk.__version__
# Out:
# pandas version:  0.13.1
# numpy version: 1.8.1
# sklearn version: 0.14.1

# %%
import sys
home_dir='/home/ubuntu/panagosg7'
sys.path.append(home_dir+'/utils')
from find_waiting_flow import *
from AWS_keypair_management import *

# %% [markdown]
# ###Load code

# %%
# load from separate file
# %run hierarchical_indexing_1.py
# Out:
# pandas version:  0.13.1
# numpy version: 1.8.1
# sklearn version: 0.14.1

# %%
Polygon
# Out:
# matplotlib.patches.Polygon

# %% [markdown]
# ### Create Hierarchy Index

# %%
import pickle
import gzip

## INPUTS

# the dataframe containing stations with 'weight' information
f = gzip.open( 'weighted_stations.pklz', "rb" )
weighted_stations = pickle.load(f)

# the number of levels of the index tree
num_levels = 4

hi = HierarchicalIndexing(weighted_stations, num_levels)

# %% [markdown]
# Stations are grouped into groups indexed by a 'group_id'

# %%
grouped_stations = hi.get_stations()
grouped_stations.head()
# Out:
#              weight  longitude  latitude     g4     g3     g2     g1  group_id
# FJ000091652      58  -179.9830  -16.1330  False  False  False  False         0
# AYW00068701      37  -178.4167  -80.0167  False  False  False  False         0
# NZ000093994     158  -177.9170  -29.2500  False  False  False  False         0
# USW00022703       7  -177.3833   28.2167  False  False  False  False         0
# MQW00022701     536  -177.3833   28.2000  False  False  False  False         0
#
# [5 rows x 8 columns]

# %% [markdown]
# ###Dump stations' file

# %% [markdown]
# Create a "pickled" file that will contain all stations and the group to which each one belongs.

# %%
import gzip
f = gzip.open('grouped_stations.pklz','wb')
pickle.dump(grouped_stations,f)
f.close()

# %% [markdown]
# ###Dump neighbors' file

# %% [markdown]
# Create a "pickled" file that will contain neighboring groups.

# %% [markdown]
# `neighbors` is a two dimentional array of size $group\_no \times group\_no$.

# %%
neighbors = hi.get_neighbors()
shape(neighbors)
# Out:
# (16, 16)

# %%
import gzip
f = gzip.open('neighbors.pklz','wb')
pickle.dump(neighbors,f)
f.close()

# %% [markdown]
# ##Plot group map

# %% [markdown]
# The following functions creates a polygon (in our case a rectangle
# that corresponds to the input longitudes (`west`, `east`) and latitudes
# (`south`, `north`). Each group is labeled by the group id `gid`.

# %%
def draw_screen_poly(hi, plt, gid, poly, m, color, text=True):
    """
    Parameters
    ----------
    plt     : the map plot
    gid     : group's id
    poly    : Polygon
    m       : basemap
    color   : color of the rectangle
    text    : print group_id tags on each group on the map (default: True)
    
    Effect
    ------
    Renders a `color` colored rectangle on the map
    """
    def fix(x):
        if x >  80: return 80.0
        if x < -80: return -80.0
        return x
    
    lons, lats = hi.polygon_to_lists(poly)

    lats = map(fix, lats)

    x, y = m( lons, lats )
    print x, y
    xy = zip(x,y)
    
    matplotlib_poly = Polygon( xy, facecolor=color, alpha=0.4, label = str(gid) )
    
    if text:
        # center    
        clon, clat = poly.center()
        clat = fix(clat)
        
        cx,cy = m([clon],[clat])
        plt.text(cx[0], cy[0], str(gid), 
                 horizontalalignment='center', 
                 verticalalignment='center',matplotlib_poly
                 bbox=dict(facecolor='white', alpha=1),
                 size =15, fontweight='bold')  
    
    z
    plt.gca().add_patch(poly)

# %%
# Taken from here: http://bensouthgate.com/p/12_3_13.php

def hex_to_RGB(hex):
    ''' "#FFFFFF" -> [255,255,255] '''
    # Pass 16 to the integer function for change of base
    return [int(hex[i:i+2], 16) for i in range(1,6,2)] 


def RGB_to_hex(RGB):
    ''' [255,255,255] -> "#FFFFFF" '''
    # Components need to be integers for hex to make sense
    RGB = [int(x) for x in RGB]
    return "#"+"".join(["0{0:x}".format(v) if v < 16 else 
                        "{0:x}".format(v) for v in RGB])
    


def color_dict(gradient):
    ''' Takes in a list of RGB sub-lists and returns dictionary of 
        colors in RGB and hex form for use in a graphing function 
        defined later on '''
    return {"hex":[RGB_to_hex(RGB) for RGB in gradient],
            "r":[RGB[0] for RGB in gradient],
            "g":[RGB[1] for RGB in gradient],
            "b":[RGB[2] for RGB in gradient]}


def linear_gradient(start_hex, finish_hex="#FFFFFF", n=10):
    ''' returns a gradient list of (n) colors between two hex colors.
        start_hex and finish_hex should be the full six-digit color string, 
        inlcuding the number sign ("#FFFFFF") '''
    # Starting and ending colors in RGB form
    s = hex_to_RGB(start_hex)
    f = hex_to_RGB(finish_hex)
    # Initilize a list of the output colors with the starting color
    RGB_list = [s]
    # Calcuate a color at each evenly spaced value of t from 1 to n
    for t in range(1, n):
        # Interpolate RGB vector for color at the current value of t
        curr_vector = [ int(s[j] + (float(t)/(n-1))*(f[j]-s[j])) 
                        for j in range(3)]
        # Add it to our list of output colors
        RGB_list.append(curr_vector)

    return color_dict(RGB_list)

# %% [markdown]
# ### Plot global map with all groups

# %%
# http://matplotlib.org/basemap/users/merc.html

from mpl_toolkits.basemap import Basemap
import numpy as np

import matplotlib.pyplot as plt

# llcrnrlat,llcrnrlon,urcrnrlat,urcrnrlon
# are the lat/lon values of the lower left and upper right corners
# of the map.

lonmin=-180;lonmax=180;latsmin=-80;latsmax=80;
# lat_ts is the latitude of true scale.
# resolution = 'i' means use intermediate resolution coastlines.
plt.figure(figsize=(15,10),dpi=300)

m = Basemap(projection='merc', 
            llcrnrlat=latsmin,urcrnrlat=latsmax,\
            llcrnrlon=lonmin,urcrnrlon=lonmax, \
            lat_ts=20,
            resolution='c')  # 'l','i'

m.drawcoastlines()
m.fillcontinents(color='coral',lake_color='aqua')
m.drawmapboundary(fill_color='aqua')


light = 'CCFFCC'
dark  = '003300'
colors = linear_gradient(light, dark, 2**num_levels)['hex']

groups = hi.get_groups()

for (idx, color) in zip(groups.keys(), colors):
    _, poly2 = groups[idx]
    print poly2.center()
    draw_screen_poly(hi, plt, idx, poly2, m, color)

plt.title('weather stations partitioning')
plt.show()
# Out:
# (-138.75930000000002, -27.833600000000008)
# [0.0, 8618399.23839614, 8618399.23839614, 0.0] [-1.0745599865913391e-05, -1.0745599865913391e-05, 18408891.44579891, 18408891.44579891]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-263ac7517d99> in <module>()
#      35     _, poly2 = groups[idx]
#      36     print poly2.center()
# ---> 37     draw_screen_poly(hi, plt, idx, poly2, m, color)
#      38
#      39 plt.title('weather stations partitioning')
#
# <ipython-input-79-55ca3ab99dfe> in draw_screen_poly(hi, plt, gid, poly, m, color, text)
#      31     if text:
#      32         # center
# ---> 33         clon, clat = poly.center()
#      34         clat = fix(clat)
#      35
#
# AttributeError: 'Polygon' object has no attribute 'center'

# %% [markdown]
# ## Draw a random group `i` and all its neighbors

# %%
# http://matplotlib.org/basemap/users/merc.html

from mpl_toolkits.basemap import Basemap
import numpy as np

import matplotlib.pyplot as plt

lonmin=-180;lonmax=180;latsmin=-80;latsmax=80;
plt.figure(figsize=(15,10),dpi=300)
m = Basemap(projection='merc', 
            llcrnrlat=latsmin,urcrnrlat=latsmax,\
            llcrnrlon=lonmin,urcrnrlon=lonmax, \
            lat_ts=20,
            resolution='c')  # 'l','i'
m.drawcoastlines()
m.fillcontinents(color='coral',lake_color='aqua')
m.drawmapboundary(fill_color='aqua')




# Draw group `i` and all neighbors

from random import randint

groups = hi.get_groups()

# pick a random group
g = randint(0,2**num_levels-1)
dark  = '#003300'
row = groups.loc[g]

# draw it
draw_screen_poly(plt, g, row.west, row.east, row.south, row.north, m, dark)

# find its neighbors
neighbors = [ n for n in hi.get_neighbors_of(g) ]

light = '#CCFFCC'
for neighbor in neighbors:
    row = groups.loc[neighbor]
    draw_screen_poly(plt, neighbor, row.west, row.east, row.south, row.north, m, light)

# plt.legend()
plt.title('Group ' + str(g) + ' and its neighbors'  )
plt.show()

# %%
# !python -v
# Out:
# # installing zipimport hook
# import zipimport # builtin
# # installed zipimport hook
# # /home/ubuntu/anaconda/lib/python2.7/site.pyc matches /home/ubuntu/anaconda/lib/python2.7/site.py
# import site # precompiled from /home/ubuntu/anaconda/lib/python2.7/site.pyc
# # /home/ubuntu/anaconda/lib/python2.7/os.pyc matches /home/ubuntu/anaconda/lib/python2.7/os.py
# import os # precompiled from /home/ubuntu/anaconda/lib/python2.7/os.pyc
# import errno # builtin
# import posix # builtin
# # /home/ubuntu/anaconda/lib/python2.7/posixpath.pyc matches /home/ubuntu/anaconda/lib/python2.7/posixpath.py
# import posixpath # precompiled from /home/ubuntu/anaconda/lib/python2.7/posixpath.pyc
# # /home/ubuntu/anaconda/lib/python2.7/stat.pyc matches /home/ubuntu/anaconda/lib/python2.7/stat.py
# import stat # precompiled from /home/ubuntu/anaconda/lib/python2.7/stat.pyc
# # /home/ubuntu/anaconda/lib/python2.7/genericpath.pyc matches /home/ubuntu/anaconda/lib/python2.7/genericpath.py
# ...

# %% [markdown]
# ##PCA - inline

# %%
# %%writefile pca.py
#!/usr/bin/python

"""
<description here>
"""

import sys
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re
from sys import stderr
import gzip
import pickle
import numpy as np
import pandas as pd

class MRPCA(MRJob):

    def configure_options(self):
        super(MRPCA,self).configure_options()
        self.add_file_option('--stations')
    
    def mapper_init(self):
        f = gzip.open( self.options.stations, "rb" )
        pickleFile = pickle.Unpickler( f )
        self.stations = pickleFile.load()[['latitude','longitude','group_id']]
        f.close()
    
    def mapper(self, _, line):
        try:
            self.increment_counter('MrJob Counters','mapper-all',1)
            elements = line.split(',')
            
            # only include TMIN measurements
            if elements[1] == 'TMAX':

                st_id = elements[0]

                # the group_id of the station in the current 
                group_id = int(self.stations.loc[st_id]['group_id'])

                # pack just the content back into an comma separated string
                yield (group_id, ','.join(elements[3:]))
        
        except KeyError as e:
            stderr.write('Key was not found.\n')
            
        except Exception as e:
            stderr.write('Error in line:\n'+line)
            stderr.write(str(e))
            self.increment_counter('MrJob Counters','mapper-error',1)
            
            
#     def combiner(self, key, values):
#         self.increment_counter('MrJob Counters','combiner',1)                
#         yield (key, values)


    # PCA is run on the reducer
    
    def reducer(self, group_id, values):
        self.increment_counter('MrJob Counters','reducer',1)        

        def to_int(s):
            if s=='': 
                return np.NaN 
            else: 
                return int(s)
        
        vrows = [ v for v in values ]
        
        # FIXME: 
        # can we use `np.fromstring('s', dtype=int, sep=',')` here ?
        # it seems that the absent value is translated into `0` instead of NaN                
        Data=pd.DataFrame([map(to_int, v.split(',')) for v in vrows], columns=range(1,366))
        
        # Normalize data (from weather notebook)
        G=Data.ix[:,1:365]
        G[G<-400]=np.NaN
        G[G>500]=np.NaN
        G=G/10
        Data.ix[:,1:365]=G
        
        from numpy import mean, std
        
        # Scale by Mean Std
        def scale_temps(Din):
            matrix=Din.iloc[:,:]
            Dout=Din.loc[:,range(1,366)]
            Mean=mean(matrix, axis=1).values
            Dout['Mean']=Mean
            Std= std(matrix, axis=1).values
            Dout['Std']=Std
            Dout.loc[:,1:365]=matrix.values
            return Dout
        Dout=scale_temps(Data)
        
        # Dout = Scale(Data) + 'mean' + 'std'
        Dout=Dout[['Mean','Std']+range(1,366)]
        
        # Calculate covariance
        M=Dout.loc[:,1:365].transpose()
        M=M.dropna(axis=1)
        (columns,rows)=M.shape
        Mean=mean(M, axis=1).values

        
        C=np.zeros([columns,columns])   # Sum
        N=np.zeros([columns,columns])   # Counter of non-nan entries
        
        for i in range(rows):
            row = M.iloc[:,i]-Mean;
            outer = np.outer(row,row)
            valid = np.isnan(outer)==False
            C[valid] = C[valid]+outer[valid]  # update C with the valid location in outer
            N[valid] = N[valid]+1
        valid_outer = np.multiply(1-np.isnan(N),N>0)
        cov = np.divide(C,N)
        
        # SVD
        U,D,V=np.linalg.svd(cov)
        
        # explained variance
        series = np.cumsum(D[:])/np.sum(D)
        
                
        # Dump some output
        stderr.write('### reducer for group: ' + str(group_id) + ' no rows: ' \
                     + str(len(vrows)) + ', cov: ' + str(cov.shape) + '\n')
        
        yield (group_id, ','.join([str(len(vrows))] + [str(i) for i in series]))
        
        # output format
        #
        # <group_id> "<no_of_measurement>,<e1>,<e2>,...,<e365>"
        #
        # where ei is the explained covariance with i eigenvectors
        
if __name__ == '__main__':
    MRPCA.run()
# Out:
# Overwriting pca.py

# %%
output_dir = '/home/ubuntu/panagosg7/notebooks/weather.mapreduce/output/'
# !mkdir -p $output_dir

# %%
#local_data = '/home/ubuntu/panagosg7/data/weather/ALL.head.csv'
local_data = '/home/ubuntu/data/weather/SAMPLE_TMAX.csv'
# !ls $local_data

local_output_file = output_dir + 'pca_local.txt'

# !python pca.py $local_data --stations grouped_stations.pklz > $local_output_file
# Out:
# /home/ubuntu/data/weather/SAMPLE_TMAX.csv
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/pca.ubuntu.20140525.051353.100783
# writing to /tmp/pca.ubuntu.20140525.051353.100783/step-0-mapper_part-00000
# Counters from step 1:
#   MrJob Counters:
#     mapper-all: 20000
# writing to /tmp/pca.ubuntu.20140525.051353.100783/step-0-mapper-sorted
# > sort /tmp/pca.ubuntu.20140525.051353.100783/step-0-mapper_part-00000
# writing to /tmp/pca.ubuntu.20140525.051353.100783/step-0-reducer_part-00000
# ### reducer for group: 0 no rows: 1199, cov: (365, 365)
# ### reducer for group: 1 no rows: 1194, cov: (365, 365)
# ### reducer for group: 10 no rows: 1843, cov: (365, 365)
# ### reducer for group: 11 no rows: 1796, cov: (365, 365)
# ### reducer for group: 12 no rows: 1120, cov: (365, 365)
# ### reducer for group: 13 no rows: 1253, cov: (365, 365)
# ### reducer for group: 14 no rows: 1593, cov: (365, 365)
# ### reducer for group: 15 no rows: 2675, cov: (365, 365)
# ...

# %%
import re

def line_arrays(f):
    for line in f.readlines():
        matchObj = re.match(r'\s*(\d*)\s*\"(\d*),(\S*)\"\s*', line)
        i = matchObj.group(1)
        n = matchObj.group(2)
        s = matchObj.group(3)
        yield np.array([int(i), int(n)] + [ float(s) for s in s.split(',') ])
    
with open(local_output_file) as f:    
    cols  = ['group_id', 'n']+range(1,366)
    table = [ l for l in line_arrays(f) ]
    df    = pd.DataFrame(table, columns=cols).set_index('group_id')    

    df['k'] = 365-sum(isnan(df[df<0.99].ix[:,1:365]),axis=1)

    df=df[['n','k']+range(1,366)]

    groups = hi.get_groups()



    n_pairs = [ (i,j) for i in range(len(groups)) 
                      for j in range(i+1,len(groups)) 
                      if hi.are_neighbors(i,j) ]
    
    pdf = pd.DataFrame(n_pairs, columns=['fst','snd'])
    
#    pdf['k1'] =

#pdf['k1'] = df['k'] # [pdf['fst']]


# filling up columns: n1, k1, n2, k2
dfk = df[['k','n']]
pdfk = pdf.join(dfk, on='fst').rename(columns = {'k':'k1','n':'n1'})\
          .join(dfk, on='snd').rename(columns = {'k':'k2','n':'n2'})


# to fill up k3, we need to rerun...
    
    
pdfk


#pdf

#pdf


#     plot(arr)
#     xlim([0,365])
#     grid()
#     figure()
# Out:
#     fst  snd   k1    n1   k2    n2
# 0     0    1  214  1199  242  1194
# 1     0    2  214  1199  216  1239
# 2     1    2  242  1194  216  1239
# 3     1    3  242  1194  233  1038
# 4     1    4  242  1194   85   335
# 5     1    6  242  1194  182   986
# 6     2    3  216  1239  233  1038
# 7     2    8  216  1239  233  1502
# 8     2    9  216  1239  230   961
# 9     3    6  233  1038  182   986
# 10    3    9  233  1038  230   961
# 11    3   12  233  1038  249  1120
# 12    4    5   85   335  105   362
# 13    4    6   85   335  182   986
# 14    4    7   85   335  137   904
# 15    5    7  105   362  137   904
# 16    6    7  182   986  137   904
# 17    6   12  182   986  249  1120
# 18    6   13  182   986  263  1253
# 19    7   13  137   904  263  1253
# 20    8    9  233  1502  230   961
# 21    8   10  233  1502  234  1843
# 22    8   11  233  1502  260  1796
# 23    9   11  230   961  260  1796
# 24    9   12  230   961  249  1120
# 25    9   14  230   961  275  1593
# ...

# %% [markdown]
# ## PCA on EMR

# %%
emr_pca_file = output_dir + 'pca.txt'
#!python weather_01.py -r emr --emr-job-flow-id  $job_flow_id   hdfs:/weather/weather.csv   > $emr_count_file
# !python pca.py -r emr --emr-job-flow-id 'j-262J0JTFJIRLO' --stations grouped_stations.pklz /home/ubuntu/panagosg7/data/weather/ALL.head-1000.csv > $emr_pca_file
#!python pca.py -r emr --emr-job-flow-id $job_flow_id --stations grouped_stations.pklz /home/ubuntu/panagosg7/data/weather/ALL.head-1000.csv > $emr_pca_file
